# %% [markdown]
# 1\. **Kernel Density Estimate**
#
# Produce a KDE for a given distribution (by hand, not using seaborn!):
#
# * Fill a numpy array, x,  of len(N) (with N=O(100)) with a variable normally distributed, with a given mean a standard deviation
# * Fill an histogram in pyplot taking properly care about the aesthetic
#    * use a meaningful number of bins
#    * set a proper y axis label
#    * set proper value of y axis major ticks labels (e.g. you want to display only integer labels)
#    * display the histograms as data points with errors (the error being the poisson uncertainty)
# * for every element of x, create a gaussian with the mean corresponding the element value and std as a parameter that can be tuned. The std default value should be:
# $$ 1.06 * x.std() * x.size ^{-\frac{1}{5.}} $$
# you can use the scipy function `stats.norm()` for that.
# * In a separate plot (to be placed beside the original histogram), plot all the gaussian functions so obtained
# * Sum (with np.sum()) all the gaussian functions and normalize the result such that the integral matches the integral of the original histogram. For that you could use the `scipy.integrate.trapz()` method

# %%
# importing useful libraries as usual aliases
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
import pandas as pd
# these functions are used for setting various tick parameters for plots
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
# these are used in the first ex 
from scipy import stats as sps
from scipy import integrate as spi

# %%
# fixind random seed for reproducibility
npr.seed(69420)

# parameters given in the text
N = 420
mean = 1.5
std = 0.68
std_width = 3.0

# normal gaussian distribution numpy.random.normal allows to generate a N-leght array of normally disributed elements of mean and std given
x = npr.normal(mean, std, N)
# making one figure for all axes, notice that the structure is a tuple of tuples (rows, columns), the second element is a tuple
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(16,9))
# np histogram create the binning for points in range \mu \pm 3.0\sigma
# setting number of bins as the square root of N
counts, bins_edges = np.histogram(x, bins=int(np.sqrt(N)), range=((mean-std_width*std),(mean+std_width*std)))
# getting center of bins as first edge - second edge using a slicing to get elements [ 0 ; N-1 ) for left and [ 1 ; N ) for right
bin_centers =(bins_edges[:-1] + bins_edges[1:])/2.0
# setting errors as sqrt of counts as in Poisson distribution
errors = np.sqrt(counts)

# labels and co.
# plotting with errorbars, position, values, errors, label for the name
# alpha is the opacity of point, color color fo the mark and ecolor color of errorbars, elinewidth the width of errorline
# fmt set the type of mark and markersize its dimension
ax1.errorbar( bin_centers, counts, errors, label='$x$', alpha=0.85, color='black', ecolor='gray', elinewidth=0.7, fmt='o', markersize=2.)
# setting xaxrs limit as \mu \pm 3.0\sigma
ax1.set_xlim((mean-std_width*std),(mean+std_width*std))
# setting title and labels
ax1.set_title('Histo x')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$x$ counts')

# some fancy parameter science
# setting locator for major and minor (every how many values set a locator); Auto is in how many part divide the major spacing 
ax1.xaxis.set_major_locator(MultipleLocator(1.000))
ax1.xaxis.set_minor_locator(AutoMinorLocator(4))
ax1.yaxis.set_major_locator(MultipleLocator(20.000))
ax1.yaxis.set_minor_locator(AutoMinorLocator(4))
# setting dimension of labels for ticks, size and apha
ax1.tick_params(which='major', width=1.0)
ax1.tick_params(which='major', length=10)
ax1.tick_params(which='minor', width=1.0, labelsize=10)
ax1.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

# second point
# default value of std as seen in text
base_std = 1.06 * x.std()*np.power(x.shape[0], (-1.0/5.0) )
# a list of pdf as lambda function for value k at position i with std default
# to have a list comprehension of lambda function that change according to a parameter a double lambda function is needed, 
# the external one is used to pass to the main one the value of index i as a parameter and not as a view of it 
gauss_pdf = [ (lambda i : (lambda k : (sps.norm.pdf( k, loc=i, scale=base_std ))))(y) for y in x ]

# third point
range_tick = 0.001
# here I could have used linspace
range_x = np.arange((mean-std_width*std),(mean+std_width*std), range_tick)
# plotting all pdf in range with different centers
# as i cycle over the list of lambda function it assumes the nature of a function, becoming a callable object i()
# this enable to plot all functions as x, f(x)
for i in gauss_pdf : ax2.plot( range_x, i(range_x) )
#for y in x: ax2.plot( range_x, sps.norm.pdf(range_x, loc=y, scale=base_std) )

# graphical settings as before
ax2.set_title('Gaussians')
ax2.set_xlabel('$x$ in 3 std')
ax2.set_ylabel('gaussian pdf of $x$')
ax2.xaxis.set_major_locator(MultipleLocator(1.000))
ax2.xaxis.set_minor_locator(AutoMinorLocator(4))
ax2.yaxis.set_major_locator(MultipleLocator(0.500))
ax2.yaxis.set_minor_locator(AutoMinorLocator(5))
ax2.tick_params(which='major', width=1.0)
ax2.tick_params(which='major', length=10)
ax2.tick_params(which='minor', width=1.0, labelsize=10)
ax2.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

#forth point

# original histogram norm, simply the sum of all counts multiplied by the witdth of one bin
histo_norm = np.sum(counts)*(bins_edges[1]-bins_edges[0])
# final gaussian as sum of all gaussian plotted
gauss = np.sum([i(range_x) for i in gauss_pdf], axis=0)
#gauss *= histo_norm/ spi.trapezoid(gauss, range_x)
# normalization to gaussian integral, rescaled to histogram area
# the scipy function trapezoid allows to integrate a function computed over a range of point range_x
gauss /= spi.trapezoid(gauss, range_x)/(histo_norm)

# plot
ax1.plot(range_x, gauss, label='$x$', alpha=0.65, color='red', linewidth=0.7)

# %% [markdown]
# 2\. **Color-coded scatter plot**
#
# Produce a scatter plot out of a dataset with two categories
#
# * Write a function that generate a 2D datasets of 2 categories. Each category should distribute as a 2D gaussian with a given mean and std (clearly it is better to have different values means..)
# * Display the dataset in a scatter plot marking the two categories with different marker colors.
#
# An example is given below
#
# You can try to make the procedure more general by allowing a given number $n\ge 2$ of categories

# %%
# using wget to download a file from dropbox
! wget https://www.dropbox.com/s/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
# importing image to display images
from IPython.display import Image
Image('two_categories_scatter_plot.png')
# Out:
# --2024-12-05 13:47:59--  https://www.dropbox.com/s/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/70o67xqfkicx6o3pofl37/two_categories_scatter_plot.png?rlkey=b1wnq5kkwhthz0cevmq0mxf35 [following]
# --2024-12-05 13:47:59--  https://www.dropbox.com/scl/fi/70o67xqfkicx6o3pofl37/two_categories_scatter_plot.png?rlkey=b1wnq5kkwhthz0cevmq0mxf35
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc904631928251e463ba2f74c69c.dl.dropboxusercontent.com/cd/0/inline/CfrsqRhbFPX7GkHmI9yIEy5ImUyFjH2DHUHg7E36XYHCT57V2k-GmN3Ri3QxwVXQlIHwBLIbjaCHwRdMH1lT0AuZSbjbXLFDRK0nXZhmbpq5RONaK5-DkNuy5QtFYzWAnyw/file# [following]
# ...

# %%
# ex 2
# np arrays for indexes and distributions
# defining two variables tougheter
total_data_1, total_data_2 = 960, 690
# setting seed for reproducibility
npr.seed(69420)
# setting 2d means for both distributions
mean_1, mean_2 = (20, 7.6), (19.6, 8.7)
# setting std as a matrix for multidimensional gaussian distribution
std_1, std_2 = ((1.36, 0.0), (0.0, 0.53)), ((3.6, 0.0), (0.0, 0.15))
# creating indexes to separate easily two datasets, [0, max_1) and [max_1, max_1+max_2)
ind_1 = np.arange(total_data_1)
ind_2 = np.arange(total_data_1, (total_data_2+total_data_1))
# multidim gaussian variables, it requires mean and std matrix of appropriate dimensions as tuples, and allows to create different shapes of output
data_1 = npr.multivariate_normal(mean_1, std_1, (total_data_1))
data_2 = npr.multivariate_normal(mean_2, std_2, (total_data_2))
# dataframes of 2d data
# creating the first dataframe from data_1, with indexes [0, max_1) and columns names
df_1 = pd.DataFrame( data_1, index= ind_1, columns=['x', 'y'])
# adding the cat(egory) feature set to 1 for all elements in 1
df_1['cat'] = 1
# creating the first dataframe from data_1, with indexes [max_1, max_1+max_2) and columns names
df_2 = pd.DataFrame(data_2, index=ind_2, columns=['x', 'y'])
# adding the cat(egory) feature set to 2 for all elements in 2
df_2['cat'] = 2
# making a dataframe from the concatenation of the other two; having indexes ordered as seen they are put one over the other
df = pd.concat([df_1, df_2])

# making scatter plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,9))
# scattering using x column as first coordinate and y as the second one, dividing by categories using a mask 
# this allows simpicity and the possibility of seting color (c) and edgecolor for each type, and setting single labels
# it is also possible to do so using c =df['cat'] for color, setting a third variable for a 3d rapresentation
ax.scatter( x= df[df['cat']==1]['x'], y=df[df['cat']==1]['y'], marker='o', c='cyan', edgecolor='blue', label='data 1')
ax.scatter( x= df[df['cat']==2]['x'], y=df[df['cat']==2]['y'], marker='o', c='#FCDF81', edgecolor='#E27C06', label='data 2')
# setting labels and title
ax.set_title('Scatter: $x$ versus $y$')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# defining the position of the legend (quite arbitrary)
ax.legend(loc=(0.15, 0.15))
# designing precise tiks and locator for fun
ax.xaxis.set_major_locator(MultipleLocator(4.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(2.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

# %% [markdown]
# 3\. **Profile plot**
#
# Produce a profile plot from a scatter plot.
# * Download the following dataset and load it as a pandas dataframe:
# ```bash
# wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy
# ```
# Note that you should use the `np.load()` function to load the file as a numpy array, call the `.item()` method, and then pass it to the `pd.DataFrame()` constructor.
# * Inspect the dataset, you'll find two variables (features)
# * Clean the sample by selecting the entries (rows) with the variable "residual" in absolute value smaller than 2
# * perform a linear regression of "residuals" versus "distances" using `scipy.stats.linregress()`
# * plot a seaborn jointplot of  "residuals" versus "distances", having seaborn performing a linear regression. The result of the regression should be displayed on the plot
# * Fill 3 numpy arrays
#   * x, serving as an array of bin centers for the "distance" variable. It should range from 0 to 20 with reasonable number of steps (bins)
#   * y, the mean values of the "residuals", estimated in slices (bins) of "distance"
#   * erry, the standard deviation of the  of the "residuals", estimated in slices (bins) of "distance"
# * Plot the profile plot on top of the scatter plot

# %%
# loding a file using numpy; allow_pickle can be set to True because we "trust" the file origin and it contains arrays
df_261 = pd.DataFrame(np.load('residuals_261.npy', allow_pickle=True).item())
# making a vew of the masked datafile using the condition absolute_value(residual column) < 2
cleared = df_261[np.abs(df_261['residuals']) < 2]
#cleared
# using scipy stats imported before to call linregress for the xOy system distancesOresiduals
parameters = sps.linregress(cleared['distances'], cleared['residuals'])
# the output is a class of differen object labeling all parameters obtained by the regression
print(parameters)
# importing seaborn
import seaborn as sns
# making a jointplot, it takes data as a DataFrame and axes as labels, kind determines the type of graph and 
# x_jitter is an argument of regplot, that adds random noise along x (used only to visualize them not aligned)
sns.jointplot(x="distances", y="residuals", x_jitter= 1.0, data=cleared, kind='reg')
# last two points
# settings given in the text
min_b= 0.0
max_b= 20.0
n_bin = 100
# computig width of the bins
b_width = (max_b -min_b)/(n_bin)
# this could have been a linspace, but gets a range [min_b, max_b) where point have fixed distance b_width
x = np.arange(min_b, max_b, b_width)
# computing the array of centroids, taking from 0 to N-1 left position of bins and adding half width
x_centroid = x[0:-1:] + b_width/2.0
# getting y axis from a conversion of a list comprehension of the means of the cleared distances in the desired range
# the element has to be lesser than the centroid + half width and more than the centroid - half width
# here * is used instead of and because it's faster for an elementwise operation
y = np.array([ np.mean( cleared[(cleared['distances'] > (x[i] - b_width/2.)) * (cleared['distances'] < (x[i] + b_width/2.))]['residuals'] ) for i in range(n_bin-1) ])
# getting error for y axis from a conversion of a list comprehension of the std of the cleared distances in the desired range as before
erry = np.array([ np.std( cleared[(cleared['distances'] > (x[i] - b_width/2.)) * (cleared['distances'] < (x[i] + b_width/2.))]['residuals'] ) for i in range(n_bin-1) ])
# getting for x_bins the number of elements in each bin similar as before, here using shape of the result to count the entries
x_bins = np.array([ ( cleared[(cleared['distances'] > (x[i] - b_width)) * (cleared['distances'] < (x[i] + b_width))]['distances'] ).shape[0] for i in range(n_bin-1) ])
# checking if empty bins are present, using all to have True  when all elements in x_bins are grater than 0, and not to reverse that result
if ( not np.all(x_bins) ) : print( 'There are empty bins')

# profile plot of the scatter plot (?)
plot_data= pd.DataFrame(zip(x_centroid, y, erry), columns=['distances','residuals','std'], index=np.arange(1, n_bin))
# g = sns.jointplot( data=plot_data , x='distances', y='residuals', weights='std', kind="reg")
g = sns.jointplot( data=plot_data , x='distances', y='residuals', kind="reg")
fig, ax1= plt.subplots(nrows=1, ncols=1, figsize=(16,9))
ax1.errorbar( x_centroid, y, erry, label='binning', alpha=0.85, color='black', ecolor='gray', elinewidth=0.7, fmt='o', markersize=2.)
# linreg line
ax1.plot( x_centroid, (x_centroid*(parameters.slope) + (parameters.intercept)), label= 'original_linreg', alpha=0.75, color='red', linewidth=0.8)
par = sps.linregress(x_centroid, y)
ax1.plot( x_centroid, (x_centroid*(par.slope) + (par.intercept)), label= 'bin_linreg', alpha=0.75, color='blue', linewidth=0.8)

# labels and co.
ax1.set_title('Distances and residuals')
ax1.legend(loc=(0.9, 0.9))
ax1.set_xlabel('distances')
ax1.set_ylabel('residuals')

# some fancy parameter science
ax1.xaxis.set_major_locator(MultipleLocator(2.000))
ax1.xaxis.set_minor_locator(AutoMinorLocator(4))
ax1.yaxis.set_major_locator(MultipleLocator(0.1000))
ax1.yaxis.set_minor_locator(AutoMinorLocator(4))
ax1.tick_params(which='major', width=1.0)
ax1.tick_params(which='major', length=10)
ax1.tick_params(which='minor', width=1.0, labelsize=10)
ax1.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')
# Out:
# LinregressResult(slope=0.0032597701220305835, intercept=-0.15432816763069473, rvalue=0.043403510522559086, pvalue=8.717037183576464e-06, stderr=0.0007327014008445789, intercept_stderr=0.008458951961471835)
