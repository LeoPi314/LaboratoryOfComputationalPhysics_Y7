# %%
# GOD BLESS https://scipy-lectures.org

# %% [markdown]
# 1\. **Maximum wind speed prediction at the Sprogø station**
#
# The exercise goal is to predict the maximum wind speed occurring every 50 years even if no measure exists for such a period. The available data are only measured over 21 years at the Sprogø meteorological station located in Denmark.
#
# The annual maxima are supposed to fit a normal probability density function. However such function is not going to be estimated because it gives a probability from a wind speed maxima. Finding the maximum wind speed occurring every 50 years requires the opposite approach, the result needs to be found from a defined probability. That is the quantile function role and the exercise goal will be to find it. In the current model, it is supposed that the maximum wind speed occurring every 50 years is defined as the upper 2% quantile.
#
# By definition, the quantile function is the inverse of the cumulative distribution function. The latter describes the probability distribution of an annual maxima. In the exercise, the cumulative probability $p_i$ for a given year i is defined as $p_i = i/(N+1)$ with $N = 21$, the number of measured years. Thus it will be possible to calculate the cumulative probability of every measured wind speed maxima. From those experimental points, the scipy.interpolate module will be very useful for fitting the quantile function. Finally the 50 years maxima is going to be evaluated from the cumulative probability of the 2% quantile.
#
# Practically, load the dataset:
#
# ```python
# import numpy as np
# max_speeds = np.load('max-speeds.npy')
# years_nb = max_speeds.shape[0]
# ```
#
# Compute then the cumulative probability $p_i$ (`cprob`) and sort the maximum speeds from the data. Use then the  UnivariateSpline from scipy.interpolate to define a quantile function and thus estimate the probabilities.
#
# In the current model, the maximum wind speed occurring every 50 years is defined as the upper 2% quantile. As a result, the cumulative probability value will be:
#
# ```python
# fifty_prob = 1. - 0.02
# ```
#
# So the storm wind speed occurring every 50 years can be guessed as:
#
# ``` python
# fifty_wind = quantile_func(fifty_prob)
# ```

# %%
# importing block of all used libraries
import numpy as np
from numpy import random as npr
import pandas as pd
from scipy import linalg as la
from scipy import optimize as sOp
from scipy import stats
from scipy import interpolate as sIn
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
from matplotlib import colors as mpc
# %matplotlib inline

# %%
# EXAM EXERCISE

# load file
# using numpy load to convert max-speed into a np array
max_speeds = np.load('max-speeds.npy')
# number of year points is the first shape coordinate
years_nb = max_speeds.shape[0]

# define probability density function over the points
# converting into an array a list comprehension of years in [1; years_nb] divided by 1 + years_nb (this should be 21 + 1)
cprob = np.array([float(x+1.)/(float(years_nb) + 1.) for x in range(years_nb)])
# getting the quantile curve using UnivariateSpline, taking x and y as main parameters
quantile = sIn.UnivariateSpline(cprob, np.sort(max_speeds))
# probability of 2% quantile by def
fifty_prob = 1. - 0.02
# using quantile to invert the function; spline generates a function
fifty_wind = quantile(fifty_prob)
print(fifty_wind)

fig, ax= plt.subplots(nrows=1, ncols=1, figsize=(16,10))
# graph
ax.scatter( x= cprob, y=np.sort(max_speeds), marker='o', c='#FCDF81', edgecolor='#E27C06', label='wind')
ax.set_title('Scatter: max wind speed vs cprob')
ax.set_xlabel('cumulative probability')
ax.set_ylabel('wind speed')
# function
ax.plot(np.linspace(0., 1., 1000), quantile(np.linspace(0., 1., 1000)), label='interpolated',alpha=0.65, color='red', linewidth=0.7)
ax.scatter([fifty_prob], [fifty_wind], label='fifty', marker='P', c='orange', edgecolor='red')
ax.legend(loc=(0.05, 0.85))
ax.xaxis.set_major_locator(MultipleLocator(0.100))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(2.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')
# Out:
# 32.97989844019469

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18
#
# min: -62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58
#
# * Plot these temperature extremes.
# * Define a function that can describe min and max temperatures.
# * Fit this function to the data with scipy.optimize.curve_fit().
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
# EXAM EXERCISE

# point 1
# converting input data into usable arrays; defining the dtype (datatype) prevents the need to specify the float cast to make calculations
month_max = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18], dtype=float)
month_min = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58], dtype=float)
# month number are usually from 1 to 12 so [1;12] is obtained by the range [1;13)
month = np.arange(1,13)
# setting names with an empty 0th month for following graph
month_name = ["", "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
# graph
fig, ax= plt.subplots(nrows=1, ncols=1, figsize=(16,10))
# plotting basically with scatter, marker and colors for points, red for max, blue for min
ax.scatter( x= month, y=month_max, marker='o', c='#FE4C04', edgecolor='#A20606', label='max temperature')
ax.scatter( x= month, y=month_min, marker='o', c='#1B57F6', edgecolor='#0F1A8A', label='min temperature')
# setting labels and titles
ax.set_title('Max and Min temperature by month')
ax.set_xlabel('Month')
ax.set_ylabel("Temperature ($° C$)")
# putting manually legend in a convenient corner
ax.legend(loc=(0.05, 0.9))
# setting locators
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_minor_locator(AutoMinorLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(10.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')
# manually setting ticks to be only [0;12]
ax.set_xticks(np.arange(0,13))
# changing labels of ticks from numbers to month names
ax.set_xticklabels(month_name)

# point 2
# defining a function with needed varibales, easy to intepreter
# the temperature is supposed to be a periodic oscillation of amplitude A, Period T, month offset phase and temperature offset B
def sin_t( x, A, T, phase, B) :
    return ( A*np.sin( 2.*np.pi*(x + phase)/T ) + B )

# point 3
# using curve_fit to fit data using the defined function
# curve_fit takes (function, x, y, starting parameter list)
# as starting values for parameters, the diff between max and min is given for the amplitude, 12 moths as period, 6 month as x offset and the minimum for the y offset
# it returns the fitted parameters and covariance matrix
par_M, cov_M = sOp.curve_fit(sin_t, month, month_max, p0=[(month_max.max() - month_max.min()), 12., 6., month_max.min() ])
par_m, cov_m = sOp.curve_fit(sin_t, month, month_min, p0=[(month_min.max() - month_min.min()), 12., 6., month_min.min() ])
# printing results
print(par_M, '\n', par_m )
print(cov_M, '\n', cov_m )
# period is a little under 11 moths, not as good as result

# point 4, plot
# plotting all: using linspace to have N point in [1;12] included (the x values), using the fitted function to draw, with labels and fitting color
ax.plot(np.linspace(1., 12., 1000), sin_t(np.linspace(1., 12., 1000), par_M[0], par_M[1], par_M[2], par_M[3]), label='interpolated max',alpha=0.85, color='orange', linewidth=0.8)
ax.plot(np.linspace(1., 12., 1000), sin_t(np.linspace(1., 12., 1000), par_m[0], par_m[1], par_m[2], par_m[3]), label='interpolated main',alpha=0.85, color='cyan', linewidth=0.8)
ax.legend(loc=(0.05, 0.85))

# point 5
# defining time offset from the corresponding parameters
time_offset_max, time_offset_min = par_M[2], par_m[2]
# defining the errors of those from the cov matrix
offset_err_max, offset_err_min = np.sqrt(cov_M[2][2]), np.sqrt(cov_m[2][2])
# printing output using f""
print(f'Time offset are compatible for {np.abs(time_offset_max-time_offset_min)/(offset_err_min*offset_err_max)} sigma')
#t = stats.ttest_ind(npr.normal(time_offset_max, offset_err_max), npr.normal(time_offset_min, offset_err_min))
#print(f'Are time offset compatible? {t}')
# Out:
# [10.58169954 10.60857441  6.53794319 27.94963534]
#  [ 25.14962014  10.44897342   5.92822174 -36.7125682 ]
# [[ 0.16816449  0.0153838   0.01830729  0.00655243]
#  [ 0.0153838   0.1439603   0.1783188  -0.11468346]
#  [ 0.01830729  0.1783188   0.22600058 -0.14165628]
#  [ 0.00655243 -0.11468346 -0.14165628  0.1833976 ]]
#  [[ 1.72807298  0.00431193 -0.00364812  0.18919036]
#  [ 0.00431193  0.16024733  0.19377973 -0.27803042]
#  [-0.00364812  0.19377973  0.24311431 -0.33100562]
#  [ 0.18919036 -0.27803042 -0.33100562  1.41859835]]
# Time offset are compatible for 2.6011862216357162 sigma

# %% [markdown]
# 3\. **2D minimization of a six-hump camelback function**
#
# $$
# f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2
# $$
#
# has multiple global and local minima. Find the global minima of this function.
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use numpy.meshgrid() and pylab.imshow() to find visually the regions.
# * Use scipy.optimize.minimize(), optionally trying out several of its methods.
#
# How many global minima are there, and what is the function value at those points? What happens for an initial guess of $(x, y) = (0, 0)$ ?

# %%
# EXAM EXERCISE

# defining f for future uses
# f is the six-hump camelback function defined for a 2d variable x = ( x, y ), as defined by the text
def f(x):
    return (4. - 2.1 * np.power( x[0], 2 ) + np.power( x[0], 4 ) / 3. ) * np.power( x[0], 2 ) + x[0] * x[1] + (4.* np.power( x[1], 2 ) - 4. ) * np.power( x[1], 2 )

# deciding a number of partitions for the 2d space
dis = 1000

# defining points for axes x and y using linspace, so that x is made of dis points in [-2,2] and y of dis points in [-1,1]
x, y = np.linspace( -2., 2., dis ), np.linspace( -1., 1., dis)
# using meshgrid to combine two arrays into a tuple of two matrix: each one rapresent the corrisponding coordinate of the plane along a differnte axis
# each element in the matrix rapresent one of the coordinate of the grid made from the arrays
# each matrix is constant along a different axis, giving a set value while the other changes
# the names could have been xy and yx to maybe make it more clear
(xx, yy) = np.meshgrid( x, y )
# evaluating the function over the grid ( and then converting it into a np matrix, as is a list of tuples from the shape of the grid)
data = np.array(f( (xx, yy)))
# creating the figure for the plot with pyplot
fig, ax= plt.subplots(nrows=1, ncols=1, figsize=(16,10))
# using imshow to rapresent the grid: imshow uses as input the np matrix of results and extent is used to set the scale of the axes
# extent argument must be passe as a list of ordered minima and maxima of each axis
ax.imshow( data , cmap = 'Spectral_r' , extent=[x.min(), x.max(), y.min(), y.max()])
# the colorbar has to be assigned separtly if the imshow is called by axes
# here the colorbar is created using a ScalarMappable, and functions in matplotlib colors (mpc)
fig.colorbar(plt.cm.ScalarMappable( norm = mpc.Normalize(vmin=data.min(), vmax=data.max(), clip=False), cmap='Spectral_r'), ax=ax, shrink=0.67)
# a list of local minima is defined from the results displayed in the figure
# sOp (scipy optimization) calls minimize with argument the function, a first guess of the minimum and bounds for the search
minima = [
    sOp.minimize( f, (-1.75, -0.85), bounds= ((-2.,-1.5), (-1.,-0.5))) ,
    sOp.minimize( f, (0.0, -0.75), bounds= ((-0.5,0.5), (-1.,-0.25))) ,
    sOp.minimize( f, (0.0, 0.75), bounds= ((-0.5,0.5), (0.25,1.))) ,
    sOp.minimize( f, (1.75, 0.85), bounds= ((1.5,2.), (0.5,1.))) ]
# the objiect returned by minimize is a class with various parameters and so the print of all them should be readable
print(minima)
# Out:
# [  message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: 2.104250310311312
#         x: [-1.607e+00 -5.687e-01]
#       nit: 7
#       jac: [ 1.021e-06  8.882e-08]
#      nfev: 27
#      njev: 9
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>,   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: -1.0316284534898066
#         x: [ 8.984e-02 -7.127e-01]
#       nit: 5
#       jac: [-1.021e-06  8.882e-08]
#      nfev: 21
#      njev: 7
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>,   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: -1.0316284534898124
#         x: [-8.984e-02  7.127e-01]
#       nit: 5
#       jac: [ 1.021e-06 -8.882e-08]
#      nfev: 21
#      njev: 7
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>,   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
# ...

# %% [markdown]
# 4\. **FFT of a simple dataset**
#
# Performe a periodicity analysis on the lynxs-hares population

# %% [markdown]
# 5\. **FFT of an image**
#
# * Examine the provided image `moonlanding.png`, which is heavily contaminated with periodic noise. In this exercise, we aim to clean up the noise using the Fast Fourier Transform.
# * Load the image using pylab.imread().
# * Find and use the 2-D FFT function in scipy.fftpack, and plot the spectrum (Fourier transform of) the image. Do you have any trouble visualising the spectrum? If so, why?
# * The spectrum consists of high and low frequency components. The noise is contained in the high-frequency part of the spectrum, so set some of those components to zero (use array slicing).
# * Apply the inverse Fourier transform to see the resulting image.

# %%
# EXAM EXERCISE

# importing library for discrete fourier transform
from scipy import fftpack as dft
# importing data using pyplot imread to read a png as values (grayscale)
data = plt.imread('moonlanding.png')

# applying fourier trasform 2d using fft2
c_transf = dft.fft2( data )
# converting complex value frequencies to real values with abs from numpy
transf = np.abs(c_transf)

# print(transf.max(), transf.min())
# fig, axs= plt.subplots(nrows=2, ncols=1, figsize=(16,10))
# ax = axs[0]
# ax.imshow( np.log(transf) , cmap = 'Spectral_r' )
# fig.colorbar(plt.cm.ScalarMappable( norm = mpc.Normalize(vmin=np.log(transf.min()), vmax=np.log(transf.max()), clip=False), cmap='Spectral_r'), ax=ax, shrink=0.67)
# ax = axs[1]
# ax.imshow( transf , cmap = 'Spectral_r' , norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ))
# fig.colorbar(plt.cm.ScalarMappable( norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ), cmap='Spectral_r'), ax=ax, shrink=0.67)

# displaying the result of the transformation and sequent operations in 2 rows and 2 columns
fig, axs= plt.subplots(nrows=2, ncols=2, figsize=(16,10))
# first figure
ax = axs[0][0]
# using imshow to display the image (a 2d grid of values), using Logaritmic normalization to visualize hight intensity frequencies
# making the colormap with mpc
ax.imshow( transf , cmap = 'Spectral_r' , norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ))
# adding colorbar to the side to the figure, shrinking it to 90% so it is the same dim of the image
fig.colorbar(plt.cm.ScalarMappable( norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ), cmap='Spectral_r'), ax=ax, shrink=0.9)
ax.set_title('Original Spectrum')

# third figure
ax = axs[1][0]
# displaying the original image with a Normal scaling with copper scale 
ax.imshow( data , cmap = 'copper' , norm = mpc.NoNorm(vmin=data.min(), vmax=data.max(), clip=False ))
fig.colorbar(plt.cm.ScalarMappable( norm = mpc.NoNorm(vmin=data.min(), vmax=data.max(), clip=False ), cmap='copper'), ax=ax, shrink=0.9)
ax.set_title('Original Image')

# hopefully creating a copy of the original
clear_transf = c_transf
# setting lower and upper bound for frequency cut
lower = 0.075
upper = 0.925
# creating a list matrix for the upper/lower limits in both dimension to operate the cleaning
# it is done converting to int the fraction of the lenght of each dimension (N*0.9 is otherwise a float not usable as index)
limit = [ [int(c_transf.shape[0] * lower) , int(c_transf.shape[0] * upper)] , [int(c_transf.shape[1] * lower) , int(c_transf.shape[1] * upper)] , [int((c_transf.shape[0] + c_transf.shape[1]) * lower) , int((c_transf.shape[0] + c_transf.shape[1]) * upper)] ]

# various possible cleaning options

# print(limit, clear_transf.shape)

# imposing the value 0.01, a low value for other frequencies, to the middle cross frequencies
clear_transf[ limit[0][0] : limit[0][1] , : ] = 0.01
clear_transf[ : , limit[1][0] : limit[1][1] ] = 0.01

# imposing the value 0 to the higher frequencies
# clear_transf[ limit[0][0] : -1 : , limit[1][0] : -1 : ] = 0.

# clear_transf[ clear_transf  < np.power( 10, 1.5 )] = 0.
# clear_transf[ clear_transf  > np.power( 10, 2. )] = 0.
# clear_transf[ limit[0][0] : limit[0][1] , 0 : -1 ] = 0.
# clear_transf[ 0: -1 , limit[1][0] : limit[1][1] ] = 0.
# for i in range(clear_transf.shape[0]) : 
#     for j in range(clear_transf.shape[1]) :
#         if ( limit[0][0] <= i <= limit[0][1] ) :
#             if( limit[1][0] <= j <= limit[1][1]) :
#                 c_transf[i][j] = 0.
#             elif ( limit[2][0] <= (i+j) <= limit[2][1] ) : 
#                 c_transf[i][j] = 0.
#         if ( limit[1][0] <= j <= limit[1][1] ) :
#             if( limit[0][0] <= i <= limit[0][1]) :
#                 c_transf[i][j] = 0.
#             elif ( limit[2][0] <= abs(i-j) <= limit[2][1] ) : 
#                 c_transf[i][j] = 0.
# clear_transf[ limit[0][0] : limit[0][1] , limit[1][0] : limit[1][1] ][ clear_transf[ limit[0][0] : limit[0][1] , limit[1][0] : limit[1][1] ] < np.power( 10, 1. )] = 0.


# second figure
ax = axs[0][1]
## using imshow to display the image (a 2d grid of values), using Logaritmic normalization to visualize hight intensity frequencies
# making the colormap with mpc
ax.imshow( np.abs(clear_transf) , cmap = 'Spectral_r' , norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ))
# adding colorbar to the side to the figure, shrinking it to 90% so it is the same dim of the image
fig.colorbar(plt.cm.ScalarMappable( norm = mpc.LogNorm(vmin=transf.min(), vmax=transf.max(), clip=False ), cmap='Spectral_r'), ax=ax, shrink=0.9)
ax.set_title('Cleared Spectrum')


# forth figure
ax = axs[1][1]
# reverse transformation done using ifft2 as "inverse 2d fast fourier transform"
i_transf = dft.ifft2( clear_transf )
# returning absolute value and getting real number from the complex transform
clean = np.abs(i_transf)
# displaying as before
ax.imshow( clean , cmap = 'copper' , norm = mpc.NoNorm(vmin=clean.min(), vmax=clean.max(), clip=False ))
fig.colorbar(plt.cm.ScalarMappable( norm = mpc.NoNorm(vmin=clean.min(), vmax=clean.max(), clip=False ), cmap='copper'), ax=ax, shrink=0.9)
ax.set_title('Cleared Image')
# Out:
# Text(0.5, 1.0, 'Cleared Image')
